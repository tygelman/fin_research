# %%
import yfinance as yf

# Get the data for the stock AAPL
data = yf.download('AAPL','2016-01-01','2019-08-01')

# Import the plotting library
import matplotlib.pyplot as plt
# %matplotlib inline

# Plot the close price of the AAPL
data['Adj Close'].plot()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
import pandas as pd
tickers_list = ['AAPL', 'WMT', 'IBM', 'MU', 'BA', 'AXP']

# Fetch the data
import yfinance as yf
data = yf.download(tickers_list,'2015-1-1')['Adj Close']

# Print first 5 rows of the data
print(data.head())
# Out:
# [*********************100%***********************]  6 of 6 completed
#                  AAPL        AXP          BA         IBM         MU        WMT
# Date
# 2015-01-02  24.565699  82.201302  113.657227  108.148605  34.398563  72.252899
# 2015-01-05  23.873640  80.027420  112.870056  106.446907  33.438366  72.042625
# 2015-01-06  23.875893  78.321869  111.540627  104.151253  32.537571  72.597786
# 2015-01-07  24.210680  80.032440  113.272377  103.470612  31.775358  74.523933
# 2015-01-08  25.140905  81.166901  115.275261  105.719513  33.329475  76.096870

# %%
((data.pct_change()+1).cumprod()).plot(figsize=(10, 7))

# Show the legend
plt.legend()

# Define the label for the title of the figure
plt.title("Returns", fontsize=16)

# Define the labels for x-axis and y-axis
plt.ylabel('Cumulative Returns', fontsize=14)
plt.xlabel('Year', fontsize=14)

# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()

# %%
data = yf.download(tickers="AAPL", period="5d", interval="5m")
print(data.tail())
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Datetime
# 2023-03-08 15:35:00-05:00  152.330002  152.699997  152.300003  152.615005
# 2023-03-08 15:40:00-05:00  152.619995  153.009995  152.610001  152.940002
# 2023-03-08 15:45:00-05:00  152.949997  153.259995  152.929993  153.092499
# 2023-03-08 15:50:00-05:00  153.100006  153.210007  152.869995  152.949997
# 2023-03-08 15:55:00-05:00  152.940002  152.940002  152.699997  152.889999
#
#                             Adj Close   Volume
# Datetime
# 2023-03-08 15:35:00-05:00  152.615005   579962
# 2023-03-08 15:40:00-05:00  152.940002   677151
# 2023-03-08 15:45:00-05:00  153.092499   984698
# 2023-03-08 15:50:00-05:00  152.949997   942082
# 2023-03-08 15:55:00-05:00  152.889999  1853509

# %%
from datetime import datetime
import yfinance as yf
import matplotlib.pyplot as plt
  
# initialize parameters
start_date = datetime(2020, 1, 1)
end_date = datetime(2021, 1, 1)
  
# get the data
data = yf.download('SPY', start = start_date,
                   end = end_date)
  
# display
plt.figure(figsize = (20,10))
plt.title('Opening Prices from {} to {}'.format(start_date,
                                                end_date))
plt.plot(data['Open'])
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
